# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Load Dataset

# %%
train_df = pd.read_csv('fashion-mnist_train.csv')
test_df = pd.read_csv('fashion-mnist_test.csv')

# %%
train_df.shape
# Out:
# (3786, 785)

# %%
test_df.shape
# Out:
# (3778, 785)

# %%
train_df.describe()
# Out:
#              label       pixel1       pixel2       pixel3       pixel4  \
# count  3786.000000  3786.000000  3786.000000  3786.000000  3786.000000
# mean      4.450079     0.003698     0.006867     0.025357     0.105388
# std       2.870479     0.227530     0.200278     0.274676     1.982949
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     0.000000     0.000000     0.000000
# 50%       4.000000     0.000000     0.000000     0.000000     0.000000
# 75%       7.000000     0.000000     0.000000     0.000000     0.000000
# max       9.000000    14.000000    10.000000    10.000000    87.000000
#
#             pixel5       pixel6      pixel7       pixel8       pixel9  ...  \
# count  3786.000000  3786.000000  3786.00000  3786.000000  3786.000000  ...
# mean      0.201532     0.440306     0.86635     2.367406     5.807713  ...
# std       2.958508     6.164050     8.48675    14.835282    24.491381  ...
# min       0.000000     0.000000     0.00000     0.000000     0.000000  ...
# 25%       0.000000     0.000000     0.00000     0.000000     0.000000  ...
# 50%       0.000000     0.000000     0.00000     0.000000     0.000000  ...
# 75%       0.000000     0.000000     0.00000     0.000000     0.000000  ...
# max      88.000000   205.000000   198.00000   216.000000   216.000000  ...
#
#           pixel775     pixel776     pixel777     pixel778     pixel779  \
# count  3785.000000  3785.000000  3785.000000  3785.000000  3785.000000
# mean     34.907794    23.390489    16.507794    17.612946    22.931308
# std      57.863304    48.218190    41.803824    43.523365    51.796674
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%      59.000000    12.000000     0.000000     0.000000     1.000000
# max     248.000000   251.000000   251.000000   254.000000   247.000000
#
#           pixel780     pixel781     pixel782     pixel783     pixel784
# count  3785.000000  3785.000000  3785.000000  3785.000000  3785.000000
# mean     18.443593     9.123118     2.824042     0.687715     0.062880
# std      46.349720    30.868680    17.360291     7.999849     1.794035
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max     255.000000   234.000000   217.000000   199.000000    74.000000
#
# [8 rows x 785 columns]

# %%
train_df.label.unique()
# Out:
# array([2, 9, 6, 0, 3, 4, 5, 8, 7, 1])

# %% [markdown]
# Each row represents an grayscale image containing 784 pixels and each pixel having values in range from 0-255
# The column label is a discrete value in the range 0 to 9 each value representing a specific category

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# Preprocess Data
# Convert each image of 784 into (28x28x1)(height x width x color_channels). Divide values by 255 to scale the values.

# %%
x_train = train_df.iloc[:,1:].to_numpy()
x_train = x_train.reshape([-1,28,28,1])
x_train = x_train / 255

# %%
y_train = train_df.iloc[:,0].to_numpy()
x_test = test_df.iloc[:,1:].to_numpy()
x_test = x_test.reshape([-1,28,28,1])
x_test = x_test / 255
y_test = test_df.iloc[:,0].to_numpy()

# %% [markdown]
# Visualization

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# Model Building

# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,Dropout

# %%
model = Sequential()

model.add(Conv2D(filters=64,kernel_size=(3,3),input_shape=(28,28,1),activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(rate=0.3))
model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=10, activation='sigmoid'))
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  dropout (Dropout)           (None, 13, 13, 64)        0
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 32)                346144
#
#  dense_1 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 347,114
# Trainable params: 347,114
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=50,batch_size=1200,validation_split=0.05)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 4s 1s/step - loss: 2.1190 - accuracy: 0.2642 - val_loss: nan - val_accuracy: 0.4158
# Epoch 2/50
# 3/3 [==============================] - 5s 1s/step - loss: 1.5988 - accuracy: 0.4358 - val_loss: nan - val_accuracy: 0.6316
# Epoch 3/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.2529 - accuracy: 0.5945 - val_loss: nan - val_accuracy: 0.7158
# Epoch 4/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.0162 - accuracy: 0.6755 - val_loss: nan - val_accuracy: 0.8053
# Epoch 5/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.8703 - accuracy: 0.7303 - val_loss: nan - val_accuracy: 0.8263
# Epoch 6/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.7681 - accuracy: 0.7500 - val_loss: nan - val_accuracy: 0.8368
# Epoch 7/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.7039 - accuracy: 0.7617 - val_loss: nan - val_accuracy: 0.8316
# Epoch 8/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.6567 - accuracy: 0.7720 - val_loss: nan - val_accuracy: 0.8579
# Epoch 9/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.6248 - accuracy: 0.7786 - val_loss: nan - val_accuracy: 0.8526
# Epoch 10/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.5972 - accuracy: 0.7925 - val_loss: nan - val_accuracy: 0.8632
# Epoch 11/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.5681 - accuracy: 0.8059 - val_loss: nan - val_accuracy: 0.8579
# Epoch 12/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.5453 - accuracy: 0.8034 - val_loss: nan - val_accuracy: 0.8632
# Epoch 13/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.5277 - accuracy: 0.8123 - val_loss: nan - val_accuracy: 0.8632
# Epoch 14/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.5101 - accuracy: 0.8181 - val_loss: nan - val_accuracy: 0.8842
# Epoch 15/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.4916 - accuracy: 0.8279 - val_loss: nan - val_accuracy: 0.8895
# Epoch 16/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.4796 - accuracy: 0.8334 - val_loss: nan - val_accuracy: 0.9000
# Epoch 17/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.4666 - accuracy: 0.8382 - val_loss: nan - val_accuracy: 0.9105
# Epoch 18/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.4550 - accuracy: 0.8398 - val_loss: nan - val_accuracy: 0.9053
# Epoch 19/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.4468 - accuracy: 0.8501 - val_loss: nan - val_accuracy: 0.9053
# Epoch 20/50
# 3/3 [==============================] - 4s 2s/step - loss: 0.4311 - accuracy: 0.8518 - val_loss: nan - val_accuracy: 0.9158
# Epoch 21/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.4239 - accuracy: 0.8546 - val_loss: nan - val_accuracy: 0.9053
# Epoch 22/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.4161 - accuracy: 0.8554 - val_loss: nan - val_accuracy: 0.9105
# Epoch 23/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.4083 - accuracy: 0.8587 - val_loss: nan - val_accuracy: 0.8947
# Epoch 24/50
# 3/3 [==============================] - 4s 2s/step - loss: 0.4063 - accuracy: 0.8568 - val_loss: nan - val_accuracy: 0.9053
# Epoch 25/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.3940 - accuracy: 0.8610 - val_loss: nan - val_accuracy: 0.8947
# Epoch 26/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.3870 - accuracy: 0.8682 - val_loss: nan - val_accuracy: 0.9105
# Epoch 27/50
# 3/3 [==============================] - 7s 1s/step - loss: 0.3772 - accuracy: 0.8640 - val_loss: nan - val_accuracy: 0.8947
# Epoch 28/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.3741 - accuracy: 0.8657 - val_loss: nan - val_accuracy: 0.9105
# Epoch 29/50
# 3/3 [==============================] - 7s 3s/step - loss: 0.3680 - accuracy: 0.8737 - val_loss: nan - val_accuracy: 0.9105
# Epoch 30/50
# 3/3 [==============================] - 13s 6s/step - loss: 0.3638 - accuracy: 0.8726 - val_loss: nan - val_accuracy: 0.9105
# Epoch 31/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.3509 - accuracy: 0.8813 - val_loss: nan - val_accuracy: 0.9211
# Epoch 32/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.3541 - accuracy: 0.8771 - val_loss: nan - val_accuracy: 0.9158
# Epoch 33/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.3422 - accuracy: 0.8799 - val_loss: nan - val_accuracy: 0.9053
# Epoch 34/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.3447 - accuracy: 0.8788 - val_loss: nan - val_accuracy: 0.9105
# Epoch 35/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.3399 - accuracy: 0.8790 - val_loss: nan - val_accuracy: 0.9105
# Epoch 36/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.3298 - accuracy: 0.8913 - val_loss: nan - val_accuracy: 0.9211
# Epoch 37/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.3226 - accuracy: 0.8896 - val_loss: nan - val_accuracy: 0.9105
# Epoch 38/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.3165 - accuracy: 0.8907 - val_loss: nan - val_accuracy: 0.9158
# Epoch 39/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.3154 - accuracy: 0.8888 - val_loss: nan - val_accuracy: 0.9211
# Epoch 40/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.3142 - accuracy: 0.8915 - val_loss: nan - val_accuracy: 0.9263
# Epoch 41/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.3110 - accuracy: 0.8932 - val_loss: nan - val_accuracy: 0.9105
# Epoch 42/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.3013 - accuracy: 0.8954 - val_loss: nan - val_accuracy: 0.9368
# Epoch 43/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.2993 - accuracy: 0.9002 - val_loss: nan - val_accuracy: 0.9105
# Epoch 44/50
# 3/3 [==============================] - 4s 2s/step - loss: 0.2977 - accuracy: 0.8966 - val_loss: nan - val_accuracy: 0.9263
# Epoch 45/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.2960 - accuracy: 0.8963 - val_loss: nan - val_accuracy: 0.9053
# Epoch 46/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.2898 - accuracy: 0.9027 - val_loss: nan - val_accuracy: 0.9316
# Epoch 47/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.2890 - accuracy: 0.9004 - val_loss: nan - val_accuracy: 0.9158
# Epoch 48/50
# 3/3 [==============================] - 4s 1s/step - loss: 0.2802 - accuracy: 0.9018 - val_loss: nan - val_accuracy: 0.9211
# Epoch 49/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.2813 - accuracy: 0.9024 - val_loss: nan - val_accuracy: 0.9263
# Epoch 50/50
# 3/3 [==============================] - 3s 1s/step - loss: 0.2705 - accuracy: 0.9041 - val_loss: nan - val_accuracy: 0.9263

# %% [markdown]
# Evaluation

# %%
evaluation = model.evaluate(x_test,y_test)
# Out:
# 119/119 [==============================] - 1s 7ms/step - loss: nan - accuracy: 0.8555

# %%
print(f"Accuracy: {evaluation[1]}")
# Out:
# Accuracy: 0.8554790616035461

# %%
y_probas = model.predict(x_test)
# Out:
# 119/119 [==============================] - 1s 5ms/step

# %%
y_pred = y_probas.argmax(axis=-1)

# %%
y_pred
# Out:
# array([0, 1, 2, ..., 6, 7, 0])

# %%
plt.figure(figsize=(10,10),)
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap=plt.cm.binary)
#     plt.xlabel(f"True Class:{y_test[i]}")
    plt.title(f"Pred:{class_names[y_pred[i]]}")
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
num_classes = 10
class_names = ["class {}".format(i) for i in range(num_classes)]
cr = classification_report(y_test, y_pred, target_names=class_names)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.79      0.80      0.80       367
#      class 1       0.98      0.97      0.98       362
#      class 2       0.76      0.75      0.75       369
#      class 3       0.88      0.87      0.88       387
#      class 4       0.74      0.86      0.80       378
#      class 5       0.95      0.92      0.94       386
#      class 6       0.70      0.58      0.63       402
#      class 7       0.90      0.89      0.89       355
#      class 8       0.95      0.96      0.96       385
#      class 9       0.91      0.95      0.93       387
#
#     accuracy                           0.86      3778
#    macro avg       0.86      0.86      0.85      3778
# weighted avg       0.85      0.86      0.85      3778
